# %% [markdown]
# ## 流程
#
# ## 查看数据集
# user_profile_table：用户信息表；用户 ID、用户性别（ 1 ：男， 0 ：女 ）、所在城市、星座
# user_balance_table：用户申购赎回数据表；
# mfd_day_share_interest ：余额表收益率表
# mfd_bank_shibor ：上海银行间同业拆放利率（Shibor）表
